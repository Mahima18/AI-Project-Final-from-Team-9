# %%
from sklearn.base import BaseEstimator, TransformerMixin
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score, f1_score
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.tree import DecisionTreeClassifier
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn import metrics
import warnings

# %%
df = pd.read_csv('final_with_main_features.csv',sep=',')
df = df.drop(df.columns[0],axis=1)

# %%
train_percentage = 13/22
train_index = int(len(df)*train_percentage)
test_index = len(df)-train_index

# %%
df_train = df[:train_index]
df_test = df[-test_index:]

# %%
X_test = df_test.drop(["Y"],axis=1)
y_test = df_test["Y"]

# %%
X_train = df_train.drop('Y',axis=1)
y_train = df_train['Y']

# %%
def average(y_pred):
  for i in range(len(y_pred)):
    if i % 240 == 0 or (i+1) % 240 == 0:
      pass
    else: 
      average = float(y_pred[i-1] +  y_pred[i] + y_pred[i+1])/3
      if average >= 0.5:
        y_pred[i] = 1
      else:
        y_pred[i] = 0
  return y_pred

# %% [markdown]
# ## 1. Logistic Regression

# %%
clf = LogisticRegression().fit(X_train, y_train)
y_pred_1 = clf.predict(X_test)
y_pred_1 = average(y_pred_1)
y_score_1 = clf.predict_proba(X_test)[:,1]
acc1 = accuracy_score(y_test, y_pred_1)
f1_score_1 = metrics.f1_score(y_test, y_pred_1)
roc_1 = metrics.roc_auc_score(y_test, y_score_1)
print([acc1,f1_score_1,roc_1])
print(confusion_matrix(y_test, y_pred_1))

import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1],'r--')
fpr, tpr, thresholds = roc_curve(y_test, y_score_1)
plt.plot(fpr, tpr, label= 'ROC curve (area = %0.2f)' % roc_1)
plt.title('ROC Curve for Logistic Regression')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()


from sklearn.calibration import calibration_curve
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_1,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'Logistic Regression')
plt.legend(loc="lower right")
plt.title('Calibration Curve for Logistic Regression')
plt.savefig('checkdemo.eps', format='eps')
# Out:
# [0.7472222222222222, 0.7429378531073446, 0.8058333333333334]
# [[1650  510]
#  [ 582 1578]]
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## 2. Naive Bayes

# %%
clf_NB = GaussianNB()
clf_NB.fit(X_train, y_train)
pred_NB = clf_NB.predict(X_test)
pred_NB = average(pred_NB)
y_score_2 = clf_NB.predict_proba(X_test)[:,1]
acc2 = accuracy_score(y_test, pred_NB)
f1_score_2 = metrics.f1_score(y_test, pred_NB)
roc_2 = metrics.roc_auc_score(y_test, y_score_2)
print([acc2,f1_score_2,roc_2])
print(confusion_matrix(y_test, pred_NB))

import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1],'r--')
fpr, tpr, thresholds = roc_curve(y_test, y_score_2)
plt.plot(fpr, tpr, label= 'ROC curve (area = %0.2f)' % roc_2)
plt.title('ROC Curve for Naive Bayes')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()


from sklearn.calibration import calibration_curve
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_2,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'Naive Bayes')
plt.legend(loc="lower right")
plt.title('Calibration Curve for Naive Bayes')
# Out:
# [0.6756944444444445, 0.6856630020192955, 0.7095250342935527]
# [[1391  769]
#  [ 632 1528]]
# Text(0.5, 1.0, 'Calibration Curve for Naive Bayes')

# %% [markdown]
# ## 3. KNN

# %%
acc3_list = []
f1_score3_list = []
roc_3_list = []
from sklearn.neighbors import KNeighborsClassifier
for i in range(1,30):
    neigh = KNeighborsClassifier(n_neighbors=i)
    neigh.fit(X_train, y_train) 
    pred_KN = neigh.predict(X_test)
    pred_KN = average(pred_KN)
    y_score_3 = neigh.predict_proba(X_test)[:,1]
    acc3_list.append(accuracy_score(y_test, pred_KN))
    f1_score3_list.append(metrics.f1_score(y_test, pred_KN))
    roc_3_list.append(metrics.roc_auc_score(y_test, y_score_3))

# %%
acc3_list.index(max(acc3_list))+1
# Out:
# 4

# %%
neigh = KNeighborsClassifier(n_neighbors=acc3_list.index(max(acc3_list))+1)
neigh.fit(X_train, y_train) 
pred_KN = neigh.predict(X_test)
pred_KN = average(pred_KN)
y_score_3 = neigh.predict_proba(X_test)[:,1]
acc3 = accuracy_score(y_test, pred_KN)
f1_score_3 = metrics.f1_score(y_test, pred_KN)
roc_3 = metrics.roc_auc_score(y_test, y_score_3)
print([acc3,f1_score_3,roc_3])
print(confusion_matrix(y_test, pred_KN))


import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1],'r--')
fpr, tpr, thresholds = roc_curve(y_test, y_score_3)
plt.plot(fpr, tpr, label= 'ROC curve (area = %0.2f)' % roc_3)
plt.title('ROC Curve for KNN')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()


from sklearn.calibration import calibration_curve
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_3,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'KNN')
plt.legend(loc="lower right")
plt.title('Calibration Curve for KNN')
# Out:
# [0.8340277777777778, 0.8038303693570451, 0.9089423653978052]
# [[2134   26]
#  [ 691 1469]]
# Text(0.5, 1.0, 'Calibration Curve for KNN')

# %% [markdown]
# ## 5. Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
acc5=[]
max_depth = []
for i in [2,3,4,5,6,7,8,9,10]:
    clf_DT = DecisionTreeClassifier(random_state=0, max_depth = i)
    clf_DT.fit(X_train, y_train)
    pred_DT = clf_DT.predict(X_test)
    pred_DT = average(pred_DT)
    acc5.append(accuracy_score(pred_DT, y_test))
    max_depth.append(i)
print (max(acc5))
# Out:
# 0.837037037037037

# %%
 best_depth = max_depth[acc5.index(max(acc5))]

# %%
 best_depth
# Out:
# 9

# %%
clf_DT = DecisionTreeClassifier(random_state=0, max_depth = best_depth)
clf_DT.fit(X_train, y_train)
pred_DT = clf_DT.predict(X_test)
pred_DT = average(pred_DT)
y_score_5 = clf_DT.predict_proba(X_test)[:,1]
acc5 = accuracy_score(y_test, pred_DT)
f1_score_5 = metrics.f1_score(y_test, pred_DT)
roc_5 = metrics.roc_auc_score(y_test, y_score_5)
print([acc5,f1_score_5,roc_5])
print(confusion_matrix(y_test, pred_DT))



import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1],'r--')
fpr, tpr, thresholds = roc_curve(y_test, y_score_5)
plt.plot(fpr, tpr, label= 'ROC curve (area = %0.2f)' % roc_5)
plt.title('ROC Curve for Decision Tree')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()


from sklearn.calibration import calibration_curve
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_5,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'Decision Tree')
plt.legend(loc="lower right")
plt.title('Calibration Curve for Decision Tree')
# Out:
# [0.837037037037037, 0.8085916258836323, 0.9169083290466391]
# [[2129   31]
#  [ 673 1487]]
# Text(0.5, 1.0, 'Calibration Curve for Decision Tree')

# %% [markdown]
# ## 6. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
acc6=[]
max_depth = []
for i in range(1,10):
    clf_RF = RandomForestClassifier(max_depth=i)
    clf_RF.fit(X_train, y_train) 
    pred_RF = clf_RF.predict(X_test)
    pred_RF = average(pred_RF)
    acc6.append(accuracy_score(pred_RF, y_test))
    max_depth.append(i)
print (max(acc6))
# Out:
# 0.8159722222222222

# %%
best_depth_6 = max_depth[acc6.index(max(acc6))]

# %%
best_depth_6
# Out:
# 9

# %%
clf_RF = RandomForestClassifier(max_depth=best_depth_6)
clf_RF.fit(X_train, y_train) 
pred_RF = clf_RF.predict(X_test)
pred_RF = average(pred_RF)
y_score_6 = clf_RF.predict_proba(X_test)[:,1]
acc6 = accuracy_score(y_test, pred_RF)
f1_score_6 = metrics.f1_score(y_test, pred_RF)
roc_6 = metrics.roc_auc_score(y_test, y_score_6)
print([acc6,f1_score_6,roc_6])
print(confusion_matrix(y_test, pred_RF))

feature_importances = pd.DataFrame(clf_RF.feature_importances_,
                                   index = X_train.columns,
                                    columns=['importance']).sort_values('importance',ascending=False)


import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1],'r--')
fpr, tpr, thresholds = roc_curve(y_test, y_score_6)
plt.plot(fpr, tpr, label= 'ROC curve (area = %0.2f)' % roc_6)
plt.title('ROC Curve for Random Forest')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()


from sklearn.calibration import calibration_curve
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_6,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'Random Forest')
plt.legend(loc="lower right")
plt.title('Calibration Curve for Random Forest')
# Out:
# [0.8233796296296296, 0.8443174862273005, 0.9395147462277093]
# [[1488  672]
#  [  91 2069]]
# Text(0.5, 1.0, 'Calibration Curve for Random Forest')

# %%
feature_importances
# Out:
#                importance
# MAR_N            0.218477
# MAR              0.184529
# MOE_N            0.148568
# Circularity      0.112672
# MOE              0.093769
# Circularity_N    0.091025
# EAR_N            0.087984
# EAR              0.062976

# %%
X_train_shaped = np.expand_dims(X_train, axis=2)

# %%
X_train_shaped.shape
# Out:
# (6240, 8, 1)

# %%
X_test_shaped = np.expand_dims(X_test, axis=2)

# %%
X_test_shaped.shape
# Out:
# (4320, 8, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers.convolutional import Conv1D
from keras.optimizers import Adam, RMSprop
from keras.layers import Dropout
## Create Model ##

model = Sequential()

model.add(Conv1D(64, kernel_size = 3, activation = 'relu', input_shape = (8,1)))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(1,activation = 'sigmoid'))


## Compile Model ##
optimizer = Adam(lr=0.00001)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

## Train Model and Check Validation Accuracy ##
model.fit(X_train_shaped, y_train, validation_data = (X_test_shaped,y_test), epochs = 100)
# Out:
# Using TensorFlow backend.
# Train on 6240 samples, validate on 4320 samples
# Epoch 1/100
# 6240/6240 [==============================] - 2s 277us/step - loss: 0.6846 - accuracy: 0.5776 - val_loss: 0.6731 - val_accuracy: 0.6530
# Epoch 2/100
# 6240/6240 [==============================] - 1s 156us/step - loss: 0.6696 - accuracy: 0.6168 - val_loss: 0.6560 - val_accuracy: 0.6720
# Epoch 3/100
# 6240/6240 [==============================] - 1s 154us/step - loss: 0.6602 - accuracy: 0.6349 - val_loss: 0.6497 - val_accuracy: 0.6766
# Epoch 4/100
# 6240/6240 [==============================] - 1s 135us/step - loss: 0.6490 - accuracy: 0.6500 - val_loss: 0.6438 - val_accuracy: 0.6819
# Epoch 5/100
# 6240/6240 [==============================] - 1s 156us/step - loss: 0.6439 - accuracy: 0.6633 - val_loss: 0.6420 - val_accuracy: 0.6769
# Epoch 6/100
# 6240/6240 [==============================] - 1s 135us/step - loss: 0.6431 - accuracy: 0.6457 - val_loss: 0.6382 - val_accuracy: 0.6775
# Epoch 7/100
# 6240/6240 [==============================] - 1s 157us/step - loss: 0.6360 - accuracy: 0.6575 - val_loss: 0.6344 - val_accuracy: 0.6822
# Epoch 8/100
# 6240/6240 [==============================] - 1s 150us/step - loss: 0.6305 - accuracy: 0.6625 - val_loss: 0.6312 - val_accuracy: 0.6866
# Epoch 9/100
# 6240/6240 [==============================] - 1s 142us/step - loss: 0.6303 - accuracy: 0.6604 - val_loss: 0.6285 - val_accuracy: 0.6900
# Epoch 10/100
# 6240/6240 [==============================] - 1s 156us/step - loss: 0.6269 - accuracy: 0.6684 - val_loss: 0.6227 - val_accuracy: 0.6981
# Epoch 11/100
# 6240/6240 [==============================] - 1s 153us/step - loss: 0.6224 - accuracy: 0.6742 - val_loss: 0.6187 - val_accuracy: 0.6977
# Epoch 12/100
# 6240/6240 [==============================] - 1s 139us/step - loss: 0.6184 - accuracy: 0.6753 - val_loss: 0.6179 - val_accuracy: 0.6970
# Epoch 13/100
# 6240/6240 [==============================] - 1s 155us/step - loss: 0.6185 - accuracy: 0.6734 - val_loss: 0.6145 - val_accuracy: 0.6998
# Epoch 14/100
# 6240/6240 [==============================] - 1s 133us/step - loss: 0.6145 - accuracy: 0.6793 - val_loss: 0.6128 - val_accuracy: 0.6975
# Epoch 15/100
# 6240/6240 [==============================] - 1s 161us/step - loss: 0.6122 - accuracy: 0.6816 - val_loss: 0.6088 - val_accuracy: 0.6995
# Epoch 16/100
# 6240/6240 [==============================] - 1s 151us/step - loss: 0.6106 - accuracy: 0.6821 - val_loss: 0.6071 - val_accuracy: 0.6968
# Epoch 17/100
# 6240/6240 [==============================] - 1s 161us/step - loss: 0.6094 - accuracy: 0.6796 - val_loss: 0.6046 - val_accuracy: 0.7012
# Epoch 18/100
# 6240/6240 [==============================] - 1s 168us/step - loss: 0.6040 - accuracy: 0.6830 - val_loss: 0.6014 - val_accuracy: 0.7032
# Epoch 19/100
# 6240/6240 [==============================] - 1s 164us/step - loss: 0.6005 - accuracy: 0.6875 - val_loss: 0.5991 - val_accuracy: 0.7021
# Epoch 20/100
# 6240/6240 [==============================] - 1s 171us/step - loss: 0.6030 - accuracy: 0.6840 - val_loss: 0.5952 - val_accuracy: 0.7104
# Epoch 21/100
# 6240/6240 [==============================] - 1s 163us/step - loss: 0.6012 - accuracy: 0.6861 - val_loss: 0.5939 - val_accuracy: 0.7111
# Epoch 22/100
# 6240/6240 [==============================] - 1s 162us/step - loss: 0.5969 - accuracy: 0.6885 - val_loss: 0.5898 - val_accuracy: 0.7150
# Epoch 23/100
# 6240/6240 [==============================] - 1s 157us/step - loss: 0.5948 - accuracy: 0.6929 - val_loss: 0.5914 - val_accuracy: 0.7095
# Epoch 24/100
# 6240/6240 [==============================] - 1s 122us/step - loss: 0.5969 - accuracy: 0.6912 - val_loss: 0.5874 - val_accuracy: 0.7157
# Epoch 25/100
# 6240/6240 [==============================] - 1s 163us/step - loss: 0.5942 - accuracy: 0.6917 - val_loss: 0.5858 - val_accuracy: 0.7144
# Epoch 26/100
# 6240/6240 [==============================] - 1s 159us/step - loss: 0.5908 - accuracy: 0.6987 - val_loss: 0.5836 - val_accuracy: 0.7176
# Epoch 27/100
# 6240/6240 [==============================] - 1s 159us/step - loss: 0.5902 - accuracy: 0.6958 - val_loss: 0.5830 - val_accuracy: 0.7204
# Epoch 28/100
# 6240/6240 [==============================] - 1s 160us/step - loss: 0.5896 - accuracy: 0.6910 - val_loss: 0.5825 - val_accuracy: 0.7190
# Epoch 29/100
# 6240/6240 [==============================] - 1s 148us/step - loss: 0.5891 - accuracy: 0.6966 - val_loss: 0.5799 - val_accuracy: 0.7225
# Epoch 30/100
# 6240/6240 [==============================] - 1s 148us/step - loss: 0.5884 - accuracy: 0.6901 - val_loss: 0.5801 - val_accuracy: 0.7188
# Epoch 31/100
# 6240/6240 [==============================] - 1s 151us/step - loss: 0.5811 - accuracy: 0.6966 - val_loss: 0.5772 - val_accuracy: 0.7218
# Epoch 32/100
# 6240/6240 [==============================] - 1s 134us/step - loss: 0.5837 - accuracy: 0.7008 - val_loss: 0.5751 - val_accuracy: 0.7245
# Epoch 33/100
# 6240/6240 [==============================] - 1s 132us/step - loss: 0.5851 - accuracy: 0.7035 - val_loss: 0.5740 - val_accuracy: 0.7243
# Epoch 34/100
# 6240/6240 [==============================] - 1s 159us/step - loss: 0.5804 - accuracy: 0.7008 - val_loss: 0.5726 - val_accuracy: 0.7236
# Epoch 35/100
# 6240/6240 [==============================] - 1s 165us/step - loss: 0.5825 - accuracy: 0.7003 - val_loss: 0.5719 - val_accuracy: 0.7231
# Epoch 36/100
# 6240/6240 [==============================] - 1s 161us/step - loss: 0.5784 - accuracy: 0.7019 - val_loss: 0.5697 - val_accuracy: 0.7231
# Epoch 37/100
# 6240/6240 [==============================] - 1s 163us/step - loss: 0.5769 - accuracy: 0.7000 - val_loss: 0.5691 - val_accuracy: 0.7252
# Epoch 38/100
# 6240/6240 [==============================] - 1s 166us/step - loss: 0.5765 - accuracy: 0.7046 - val_loss: 0.5659 - val_accuracy: 0.7287
# Epoch 39/100
# 6240/6240 [==============================] - 1s 167us/step - loss: 0.5756 - accuracy: 0.7042 - val_loss: 0.5661 - val_accuracy: 0.7252
# Epoch 40/100
# 6240/6240 [==============================] - 1s 165us/step - loss: 0.5777 - accuracy: 0.7026 - val_loss: 0.5634 - val_accuracy: 0.7310
# Epoch 41/100
# 6240/6240 [==============================] - 1s 158us/step - loss: 0.5735 - accuracy: 0.7042 - val_loss: 0.5652 - val_accuracy: 0.7243
# Epoch 42/100
# 6240/6240 [==============================] - 1s 166us/step - loss: 0.5691 - accuracy: 0.7077 - val_loss: 0.5617 - val_accuracy: 0.7326
# Epoch 43/100
# 6240/6240 [==============================] - 1s 146us/step - loss: 0.5673 - accuracy: 0.7050 - val_loss: 0.5604 - val_accuracy: 0.7310
# Epoch 44/100
# 6240/6240 [==============================] - 1s 165us/step - loss: 0.5720 - accuracy: 0.7035 - val_loss: 0.5595 - val_accuracy: 0.7303
# Epoch 45/100
# 6240/6240 [==============================] - 1s 163us/step - loss: 0.5672 - accuracy: 0.7069 - val_loss: 0.5594 - val_accuracy: 0.7292
# Epoch 46/100
# 6240/6240 [==============================] - 1s 165us/step - loss: 0.5651 - accuracy: 0.7103 - val_loss: 0.5576 - val_accuracy: 0.7299
# Epoch 47/100
# 6240/6240 [==============================] - 1s 165us/step - loss: 0.5633 - accuracy: 0.7082 - val_loss: 0.5562 - val_accuracy: 0.7319
# Epoch 48/100
# 6240/6240 [==============================] - 1s 161us/step - loss: 0.5645 - accuracy: 0.7022 - val_loss: 0.5533 - val_accuracy: 0.7356
# Epoch 49/100
# 6240/6240 [==============================] - 1s 164us/step - loss: 0.5628 - accuracy: 0.7087 - val_loss: 0.5519 - val_accuracy: 0.7345
# Epoch 50/100
# 6240/6240 [==============================] - 1s 164us/step - loss: 0.5627 - accuracy: 0.7135 - val_loss: 0.5507 - val_accuracy: 0.7329
# Epoch 51/100
# 6240/6240 [==============================] - 1s 166us/step - loss: 0.5622 - accuracy: 0.7080 - val_loss: 0.5499 - val_accuracy: 0.7322
# Epoch 52/100
# 6240/6240 [==============================] - 1s 154us/step - loss: 0.5634 - accuracy: 0.7080 - val_loss: 0.5493 - val_accuracy: 0.7329
# Epoch 53/100
# 6240/6240 [==============================] - 1s 141us/step - loss: 0.5568 - accuracy: 0.7171 - val_loss: 0.5490 - val_accuracy: 0.7306
# Epoch 54/100
# 6240/6240 [==============================] - 1s 160us/step - loss: 0.5600 - accuracy: 0.7066 - val_loss: 0.5469 - val_accuracy: 0.7387
# Epoch 55/100
# 6240/6240 [==============================] - 1s 163us/step - loss: 0.5615 - accuracy: 0.7109 - val_loss: 0.5458 - val_accuracy: 0.7412
# Epoch 56/100
# 6240/6240 [==============================] - 1s 162us/step - loss: 0.5549 - accuracy: 0.7138 - val_loss: 0.5441 - val_accuracy: 0.7377
# Epoch 57/100
# 6240/6240 [==============================] - 1s 159us/step - loss: 0.5546 - accuracy: 0.7194 - val_loss: 0.5450 - val_accuracy: 0.7333
# Epoch 58/100
# 6240/6240 [==============================] - 1s 155us/step - loss: 0.5568 - accuracy: 0.7133 - val_loss: 0.5433 - val_accuracy: 0.7380
# Epoch 59/100
# 6240/6240 [==============================] - 1s 160us/step - loss: 0.5526 - accuracy: 0.7170 - val_loss: 0.5430 - val_accuracy: 0.7387
# Epoch 60/100
# 6240/6240 [==============================] - 1s 155us/step - loss: 0.5522 - accuracy: 0.7135 - val_loss: 0.5421 - val_accuracy: 0.7368
# Epoch 61/100
# 6240/6240 [==============================] - 1s 163us/step - loss: 0.5482 - accuracy: 0.7250 - val_loss: 0.5406 - val_accuracy: 0.7384
# Epoch 62/100
# 6240/6240 [==============================] - 1s 159us/step - loss: 0.5488 - accuracy: 0.7130 - val_loss: 0.5399 - val_accuracy: 0.7414
# Epoch 63/100
# 6240/6240 [==============================] - 1s 147us/step - loss: 0.5518 - accuracy: 0.7152 - val_loss: 0.5390 - val_accuracy: 0.7400
# Epoch 64/100
# 6240/6240 [==============================] - 1s 163us/step - loss: 0.5513 - accuracy: 0.7176 - val_loss: 0.5379 - val_accuracy: 0.7400
# Epoch 65/100
# 6240/6240 [==============================] - 1s 161us/step - loss: 0.5487 - accuracy: 0.7149 - val_loss: 0.5377 - val_accuracy: 0.7363
# Epoch 66/100
# 6240/6240 [==============================] - 1s 159us/step - loss: 0.5497 - accuracy: 0.7176 - val_loss: 0.5373 - val_accuracy: 0.7368
# Epoch 67/100
# 6240/6240 [==============================] - 1s 154us/step - loss: 0.5456 - accuracy: 0.7173 - val_loss: 0.5349 - val_accuracy: 0.7426
# Epoch 68/100
# 6240/6240 [==============================] - 1s 154us/step - loss: 0.5454 - accuracy: 0.7215 - val_loss: 0.5339 - val_accuracy: 0.7417
# Epoch 69/100
# 6240/6240 [==============================] - 1s 156us/step - loss: 0.5443 - accuracy: 0.7231 - val_loss: 0.5325 - val_accuracy: 0.7428
# Epoch 70/100
# 6240/6240 [==============================] - 1s 158us/step - loss: 0.5469 - accuracy: 0.7215 - val_loss: 0.5338 - val_accuracy: 0.7370
# Epoch 71/100
# 6240/6240 [==============================] - 1s 158us/step - loss: 0.5433 - accuracy: 0.7179 - val_loss: 0.5320 - val_accuracy: 0.7398
# Epoch 72/100
# 6240/6240 [==============================] - 1s 157us/step - loss: 0.5435 - accuracy: 0.7231 - val_loss: 0.5316 - val_accuracy: 0.7417
# Epoch 73/100
# 6240/6240 [==============================] - 1s 156us/step - loss: 0.5414 - accuracy: 0.7250 - val_loss: 0.5313 - val_accuracy: 0.7387
# Epoch 74/100
# 6240/6240 [==============================] - 1s 157us/step - loss: 0.5420 - accuracy: 0.7285 - val_loss: 0.5306 - val_accuracy: 0.7394
# Epoch 75/100
# 6240/6240 [==============================] - 1s 158us/step - loss: 0.5417 - accuracy: 0.7277 - val_loss: 0.5296 - val_accuracy: 0.7407
# Epoch 76/100
# 6240/6240 [==============================] - 1s 157us/step - loss: 0.5403 - accuracy: 0.7245 - val_loss: 0.5297 - val_accuracy: 0.7384
# Epoch 77/100
# 6240/6240 [==============================] - 1s 158us/step - loss: 0.5387 - accuracy: 0.7239 - val_loss: 0.5281 - val_accuracy: 0.7405
# Epoch 78/100
# 6240/6240 [==============================] - 1s 154us/step - loss: 0.5386 - accuracy: 0.7263 - val_loss: 0.5283 - val_accuracy: 0.7405
# Epoch 79/100
# 6240/6240 [==============================] - 1s 154us/step - loss: 0.5379 - accuracy: 0.7213 - val_loss: 0.5276 - val_accuracy: 0.7419
# Epoch 80/100
# 6240/6240 [==============================] - 1s 155us/step - loss: 0.5363 - accuracy: 0.7295 - val_loss: 0.5272 - val_accuracy: 0.7400
# Epoch 81/100
# 6240/6240 [==============================] - 1s 153us/step - loss: 0.5395 - accuracy: 0.7252 - val_loss: 0.5257 - val_accuracy: 0.7440
# Epoch 82/100
# 6240/6240 [==============================] - 1s 158us/step - loss: 0.5347 - accuracy: 0.7303 - val_loss: 0.5260 - val_accuracy: 0.7433
# Epoch 83/100
# 6240/6240 [==============================] - 1s 155us/step - loss: 0.5346 - accuracy: 0.7242 - val_loss: 0.5245 - val_accuracy: 0.7449
# Epoch 84/100
# 6240/6240 [==============================] - 1s 156us/step - loss: 0.5354 - accuracy: 0.7245 - val_loss: 0.5245 - val_accuracy: 0.7414
# Epoch 85/100
# 6240/6240 [==============================] - 1s 154us/step - loss: 0.5328 - accuracy: 0.7287 - val_loss: 0.5234 - val_accuracy: 0.7403
# Epoch 86/100
# 6240/6240 [==============================] - 1s 156us/step - loss: 0.5329 - accuracy: 0.7260 - val_loss: 0.5224 - val_accuracy: 0.7396
# Epoch 87/100
# 6240/6240 [==============================] - 1s 157us/step - loss: 0.5308 - accuracy: 0.7319 - val_loss: 0.5218 - val_accuracy: 0.7456
# Epoch 88/100
# 6240/6240 [==============================] - 1s 156us/step - loss: 0.5304 - accuracy: 0.7319 - val_loss: 0.5219 - val_accuracy: 0.7417
# Epoch 89/100
# 6240/6240 [==============================] - 1s 153us/step - loss: 0.5318 - accuracy: 0.7284 - val_loss: 0.5208 - val_accuracy: 0.7444
# Epoch 90/100
# 6240/6240 [==============================] - 1s 148us/step - loss: 0.5277 - accuracy: 0.7317 - val_loss: 0.5214 - val_accuracy: 0.7437
# Epoch 91/100
# 6240/6240 [==============================] - 1s 159us/step - loss: 0.5294 - accuracy: 0.7306 - val_loss: 0.5200 - val_accuracy: 0.7437
# Epoch 92/100
# 6240/6240 [==============================] - 1s 156us/step - loss: 0.5265 - accuracy: 0.7340 - val_loss: 0.5199 - val_accuracy: 0.7461
# Epoch 93/100
# 6240/6240 [==============================] - 1s 142us/step - loss: 0.5256 - accuracy: 0.7337 - val_loss: 0.5186 - val_accuracy: 0.7491
# Epoch 94/100
# 6240/6240 [==============================] - 1s 159us/step - loss: 0.5272 - accuracy: 0.7364 - val_loss: 0.5196 - val_accuracy: 0.7465
# Epoch 95/100
# 6240/6240 [==============================] - 1s 158us/step - loss: 0.5283 - accuracy: 0.7340 - val_loss: 0.5177 - val_accuracy: 0.7479
# Epoch 96/100
# 6240/6240 [==============================] - 1s 156us/step - loss: 0.5273 - accuracy: 0.7340 - val_loss: 0.5161 - val_accuracy: 0.7484
# Epoch 97/100
# 6240/6240 [==============================] - 1s 157us/step - loss: 0.5240 - accuracy: 0.7391 - val_loss: 0.5153 - val_accuracy: 0.7509
# Epoch 98/100
# 6240/6240 [==============================] - 1s 157us/step - loss: 0.5241 - accuracy: 0.7333 - val_loss: 0.5162 - val_accuracy: 0.7495
# Epoch 99/100
# 6240/6240 [==============================] - 1s 158us/step - loss: 0.5241 - accuracy: 0.7380 - val_loss: 0.5145 - val_accuracy: 0.7486
# Epoch 100/100
# 6240/6240 [==============================] - 1s 155us/step - loss: 0.5213 - accuracy: 0.7404 - val_loss: 0.5146 - val_accuracy: 0.7463

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 6, 64)             256
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 384)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                12320
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                528
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 13,121
# Trainable params: 13,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
pred_cnn = model.predict_classes(X_test_shaped)
pred_cnn = average(pred_cnn)
y_score_7 = model.predict_proba(X_test_shaped)
acc7 = accuracy_score(y_test, np.array(pred_cnn))
f1_score_7 = metrics.f1_score(y_test, pred_cnn)
roc_7 = metrics.roc_auc_score(y_test, y_score_7)
print([acc7,f1_score_7,roc_7])
print(confusion_matrix(y_test, pred_cnn))



import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1],'r--')
fpr, tpr, thresholds = roc_curve(y_test, y_score_7)
plt.plot(fpr, tpr, label= 'ROC curve (area = %0.2f)' % roc_7)
plt.title('ROC Curve for CNN')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()


from sklearn.calibration import calibration_curve
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_7,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'CNN')
plt.legend(loc="lower right")
plt.title('Calibration Curve for CNN')
# Out:
# [0.7592592592592593, 0.7801268498942917, 0.8447351894718793]
# [[1435  725]
#  [ 315 1845]]
# Text(0.5, 1.0, 'Calibration Curve for CNN')

# %%
acc_total = {'Model':['Logistic Regression','Naive Bayes', 'KNN','Decision Tree','Random Forest', 'CNN'],
        'Accuracy':[acc1,acc2, acc3, acc5,acc6,acc7]}
acc_total=pd.DataFrame(acc_total)
acc_total=acc_total.set_index('Model')
acc_total
plt.plot(acc_total['Accuracy'])
plt.xticks(rotation=45)
acc_total
# Out:
#                      Accuracy
# Model
# Logistic Regression  0.747222
# Naive Bayes          0.675694
# KNN                  0.834028
# Decision Tree        0.837037
# Random Forest        0.823380
# CNN                  0.759259

# %%
plt.figure(figsize=(10,8))
plt.plot([0, 1], [0, 1],'r--')
fpr_1, tpr_1, thresholds = roc_curve(y_test, y_score_1)
fpr_2, tpr_2, thresholds = roc_curve(y_test, y_score_2)
fpr_3, tpr_3, thresholds = roc_curve(y_test, y_score_3)
#fpr_4, tpr_4, thresholds = roc_curve(y_test, y_score_4)
fpr_5, tpr_5, thresholds = roc_curve(y_test, y_score_5)
fpr_6, tpr_6, thresholds = roc_curve(y_test, y_score_6)
fpr_7, tpr_7, thresholds = roc_curve(y_test, y_score_7)
plt.plot(fpr_1, tpr_1, label= "Logistic Regression")
plt.plot(fpr_2, tpr_2, label= "Naive Bayes")
plt.plot(fpr_3, tpr_3, label= "KNN")
#plt.plot(fpr_4, tpr_4, label= "MLP")
plt.plot(fpr_5, tpr_5, label= "Decision Tree")
plt.plot(fpr_6, tpr_6, label= "Random Forest")
plt.plot(fpr_7, tpr_7, label= "CNN")
plt.title('ROC Curves')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()

# %%
from sklearn.calibration import calibration_curve
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_1,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'Logistic Regression')
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_2,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'Naive Bayes')
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_3,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'KNN')
#fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_4,n_bins=10)
#plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 #label="%s" % 'MLP')
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_5,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'Decision Tree')
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_6,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'Random Forest')
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_7,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'CNN')
plt.legend(loc="lower right")
plt.title('Calibration Curves')
# Out:
# Text(0.5, 1.0, 'Calibration Curves')
